# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
diamonds=pd.read_csv('C:\\Users\\Emirhan\\Desktop\\DeepLearning\\Tensorflow2_and_Keras_DeepLearning\\TF_2_Notebooks_and_Data\\DATA\\diamonds.csv')

# %%
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
diamonds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  object
#  2   color    53940 non-null  object
#  3   clarity  53940 non-null  object
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.1+ MB

# %%
sns.scatterplot(x='carat',y='price',data=diamonds)
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
sns.scatterplot(x='carat',y='price',data=diamonds,alpha=0.03,edgecolor=None)
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(x='carat',y='price',data=diamonds,alpha=0.03,edgecolor=None)
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
sns.displot(diamonds['price'],bins=24)

# %%
sns.countplot(x='cut',data=diamonds)
# Out:
# <AxesSubplot:xlabel='cut', ylabel='count'>

# %%
sns.boxplot(x='cut',y='price',data=diamonds)
# Out:
# <AxesSubplot:xlabel='cut', ylabel='price'>

# %%
cut_order = ['Fair','Ideal','Good', 'Very Good','Premium' ]
sns.boxplot(x='cut',y='price',data=diamonds,order=cut_order,palette='cool')
# Out:
# <AxesSubplot:xlabel='cut', ylabel='price'>
