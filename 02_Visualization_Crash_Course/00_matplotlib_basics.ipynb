# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,3]
y=[10,20,30]

# %%
plt.plot(x,y)

# %%
# When running a .py file , you need to add plt.show() at the end of your commands
plt.plot(x,y)
plt.show()

# %% [markdown]
# ## Basic Tools
#
# We will only use pure matplotlib for really quick,basic plots.

# %%
housing=pd.DataFrame({'rooms':[1,1,2,2,2,3,3,3],
                      'price':[100,130,140,150,170,180,240,290]})

# %%
housing
# Out:
#    rooms  price
# 0      1    100
# 1      1    130
# 2      2    140
# 3      2    150
# 4      2    170
# 5      3    180
# 6      3    240
# 7      3    290

# %%
plt.scatter(housing['rooms'],housing['price'])

# %% [markdown]
# # Style Calls

# %%
plt.plot(x,y)

# %%
plt.plot(x,y)
plt.title('Title')
plt.xlabel('X label')
plt.ylabel('Y label')
# Out:
# Text(0, 0.5, 'Y label')

# %%
plt.plot(x,y,color='red',marker='o',markersize=10,linestyle='--')
plt.xlim(1,3)
plt.ylim(10,30)
# Out:
# (10.0, 30.0)
